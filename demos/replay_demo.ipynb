# %% [markdown]
# # RiichiEnv Replay Viewer Demo
#
# This notebook demonstrates how to use the standalone Replay Viewer using a sample log provided in the repo.
# The viewer works completely client-side in the browser, meaning you can save this notebook as HTML or view it on NBViewer and the replay will still be interactive.

# %%
from riichienv import RiichiEnv
from riichienv.visualizer import Replay
from riichienv.agents import RandomAgent


agent = RandomAgent()
env = RiichiEnv(game_mode="4p-red-half")
obs_dict = env.reset()
while not env.done():
    actions = {player_id: agent.act(obs)
               for player_id, obs in obs_dict.items()}
    obs_dict = env.step(actions)

scores, points, ranks = env.scores(), env.points(), env.ranks()
print(scores, points, ranks)
# Out:
# [25000, 25000, 25000, 25000] [50, 10, -10, -50] [1, 2, 3, 4]

# %%
# Replay.from_list(env.mjai_log)
log_path = '../tools/replay-visualizer/example_before_injection.jsonl'
Replay.from_jsonl(log_path)
# Out:
#         <div id="riichienv-viewer-f3b4d24a-98a2-454a-83ea-e6c02b14c3b6" style="width: 100%; min-height: 600px; border: 1px solid #ddd; box-sizing: border-box;">
#              <div style="padding: 20px; text-align: center; font-family: sans-serif; color: #666;">
#                 Loading RiichiEnv Replay...
#              </div>
#         </div>
#         <script>
#         (function() {
#             const expectedHash = "7433dde0a58cdec11df35f0039aa9622";
#
#             const runViewer = (jsCode) => {
#                 try {
#                     if (jsCode) {
#                         const script = document.createElement('script');
#                         script.text = jsCode;
#                         document.head.appendChild(script);
#                         // Store the hash after loading new code
#                         window.RiichiEnvViewerHash = expectedHash;
#                     }
#
#                     const logData = [{"type": "start_game", "names": ["0", "1", "2", "3"], "seed": [20106, 90810], "meta": {}}, {"type": "start_kyoku", "bakaze": "E", "dora_marker": "P", "kyoku": 1, "honba": 0, "kyotaku": 0, "oya": 0, "scores": [25000, 25000, 25000, 25000], "tehais": [["C", "6m", "9p", "1s", "7m", "4p", "5p", "S", "8p", "7s", "6p", "9m", "5sr"], ["7s", "4s", "1m", "4p", "2p", "6p", "1p", "8m", "W", "5p", "W", "3s", "6s"], ["E", "7m", "3p", "7p", "2m", "4s", "9m", "N", "4p", "5mr", "1p", "2p", "9s"], ["F", "1m", "9s", "7s", "8m", "9p", "2s", "2s", "6m", "8m", "5s", "2p", "C"]], "meta": {}}, {"type": "tsumo", "actor": 0, "pai": "8p", "meta": {}}, {"type": "dahai", "actor": 0, "pai": "S", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 1, "pai": "8m", "meta": {}}, {"type": "dahai", "actor": 1, "pai": "1m", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 2, "pai": "8s", "meta": {}}, {"type": "dahai", "actor": 2, "pai": "N", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 3, "pai": "4m", "meta": {}}, {"type": "dahai", "actor": 3, "pai": "1m", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 0, "pai": "5m", "meta": {}}, {"type": "dahai", "actor": 0, "pai": "1s", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 1, "pai": "S", "meta": {}}, {"type": "dahai", "actor": 1, "pai": "S", "tsumogiri": true, "meta": {}}, {"type": "tsumo", "actor": 2, "pai": "7p", "meta": {}}, {"type": "dahai", "actor": 2, "pai": "E", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 3, "pai": "8s", "meta": {}}, {"type": "dahai", "actor": 3, "pai": "9p", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 0, "pai": "6m", "meta": {}}, {"type": "dahai", "actor": 0, "pai": "9m", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 1, "pai": "3s", "meta": {}}, {"type": "dahai", "actor": 1, "pai": "1p", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 2, "pai": "P", "meta": {}}, {"type": "dahai", "actor": 2, "pai": "P", "tsumogiri": true, "meta": {}}, {"type": "tsumo", "actor": 3, "pai": "F", "meta": {}}, {"type": "dahai", "actor": 3, "pai": "2p", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 0, "pai": "1s", "meta": {}}, {"type": "dahai", "actor": 0, "pai": "1s", "tsumogiri": true, "meta": {}}, {"type": "tsumo", "actor": 1, "pai": "E", "meta": {}}, {"type": "dahai", "actor": 1, "pai": "E", "tsumogiri": true, "meta": {}}, {"type": "tsumo", "actor": 2, "pai": "2m", "meta": {}}, {"type": "dahai", "actor": 2, "pai": "9s", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 3, "pai": "4m", "meta": {}}, {"type": "dahai", "actor": 3, "pai": "C", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 0, "pai": "8p", "meta": {}}, {"type": "dahai", "actor": 0, "pai": "C", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 1, "pai": "8p", "meta": {}}, {"type": "dahai", "actor": 1, "pai": "2p", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 2, "pai": "1s", "meta": {}}, {"type": "dahai", "actor": 2, "pai": "8s", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 3, "pai": "5pr", "meta": {}}, {"type": "dahai", "actor": 3, "pai": "5s", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 0, "pai": "2s", "meta": {}}, {"type": "dahai", "actor": 0, "pai": "2s", "tsumogiri": true, "meta": {}}, {"type": "pon", "actor": 3, "target": 0, "pai": "2s", "consumed": ["2s", "2s"], "meta": {}}, {"type": "dahai", "actor": 3, "pai": "5pr", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 0, "pai": "W", "meta": {}}, {"type": "dahai", "actor": 0, "pai": "W", "tsumogiri": true, "meta": {}}, {"type": "tsumo", "actor": 1, "pai": "3m", "meta": {}}, {"type": "dahai", "actor": 1, "pai": "8p", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 2, "pai": "7m", "meta": {}}, {"type": "dahai", "actor": 2, "pai": "1s", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 3, "pai": "9s", "meta": {}}, {"type": "d ...
